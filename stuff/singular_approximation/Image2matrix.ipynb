# %%
import torch
from google.colab import drive
drive.mount('/content/gdrive')

import torch
import numpy as np
import torchvision.transforms as transforms
import torchvision

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# ...

# %%
def get_images(url = "/content/gdrive/My Drive/Програмки/SingularApproximation", Resize = True, CenterCrop = True):
  transforms = [transforms.Grayscale(num_output_channels=1)]

  if Resize == True:
    transforms.append(transforms.Resize(28))
  if CenterCrop == True:
    transforms.append(transforms.CenterCrop(28))
  transforms.append(transforms.ToTensor())

  image_datasets_to_work = torchvision.datasets.ImageFolder(root = url, transform=data_transforms_to_work)

  num_photos = len(image_datasets_to_work)

  image_datasets = []
  for x in range(len(image_datasets_to_work)):
    elem = image_datasets_to_work[x]
    elem = elem[0]
    elem = torch.squeeze(elem)
    min = torch.min(elem)
    max = torch.max(elem)

    #точка белого и точка черного
    elem = elem - min
    elem = elem / (max - min) * 255

    height, width = elem.shape
    for i in range(height):
      for j in range(width):
        if elem[i][j] < 0:
          elem[i][j] = 0
        if elem[i][j] > 255:
          elem[i][j] = 255

    #инверсия
    elem = 255 - elem
    elem = elem.numpy()
    image_datasets.append(elem)
  return image_datasets

# %%
def print_image(image):
  # plt.imshow(image, cmap='gray', vmin=0, vmax=255) # ч/б
  plt.imshow(image, cmap='gray', vmin=0, vmax=255)
  plt.xticks([])
  plt.yticks([])
  plt.show()
